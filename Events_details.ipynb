# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\GIMHANA\Desktop\TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\GIMHANA\AppData\Local\Temp\ipykernel_9672\174978008.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\GIMHANA\Desktop\TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df
# Out:
#          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
#filtering data Year of event	in 2020 and Event distance/length in 50km and 50mi

# %%
 df[(df['Event distance/length'].isin(['50km','50mi']))  & (df['Year of event']==2020 )]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
#filter data  Event name include USA

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)  == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
 df[(df['Event distance/length'].isin(['50km','50mi']))  & (df['Year of event']==2020 ) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)  == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2= df[(df['Event distance/length'].isin(['50km','50mi']))  & (df['Year of event']==2020 ) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)  == 'USA')]

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
#calculate and create a new column Athlete_age

# %%
df2['Athlete_age']=2020-df2['Athlete year of birth']
# Out:
# C:\Users\GIMHANA\AppData\Local\Temp\ipykernel_9672\817233726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_age']=2020-df2['Athlete year of birth']

# %%
#remove "h" in Athlete performance

# %%
df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\GIMHANA\AppData\Local\Temp\ipykernel_9672\2382045920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20             3:17:55
# 2539946                         20             4:02:32
# 2539947                         20             4:07:57
# 2539948                         20             4:22:02
# ...

# %%
#drop Columns

# %%
df2=df2.drop(['Athlete club','Athlete country','Athlete age category'],axis=1)

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  Athlete year of birth  \
# 2539945                         20             3:17:55                 1991.0
# 2539946                         20             4:02:32                 1981.0
# ...

# %%
df2=df2.drop(['Athlete year of birth'],axis=1)

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2539945                         20             3:17:55              M
# 2539946                         20             4:02:32              M
# 2539947                         20             4:07:57              M
# ...

# %%
#find null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete_age                  233
# dtype: int64

# %%
#drop null values

# %%
df2=df2.dropna()

# %%
df2.shape
# Out:
# (25857, 10)

# %%
#find duplicates

# %%
df2[df2.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete_age]
# Index: []

# %%
#reset index column

# %%
df2.reset_index(drop=True)
# Out:
#        Year of event Event dates  \
# 0               2020  02.02.2020
# 1               2020  02.02.2020
# 2               2020  02.02.2020
# 3               2020  02.02.2020
# 4               2020  02.02.2020
# ...              ...         ...
# 25852           2020  03.10.2020
# 25853           2020  03.10.2020
# 25854           2020  03.10.2020
# 25855           2020  03.10.2020
# 25856           2020  03.10.2020
#
#                                           Event name Event distance/length  \
# 0      West Seattle Beach Run - Winter Edition (USA)                  50km
# 1      West Seattle Beach Run - Winter Edition (USA)                  50km
# 2      West Seattle Beach Run - Winter Edition (USA)                  50km
# 3      West Seattle Beach Run - Winter Edition (USA)                  50km
# 4      West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                              ...                   ...
# ...

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete_age                  float64
# dtype: object

# %%
#change data types

# %%
df2['Athlete_age']= df2['Athlete_age'].astype(int)

# %%
df2['Athlete average speed']= df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete_age                    int32
# dtype: object

# %%
df2[df2['Event name'] == 'Everglades 50 Mile Ultra Run']
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete_age]
# Index: []

# %%
df2[df2['Athlete ID'] == 222509]
# Out:
#          Year of event Event dates                          Event name  \
# 2591482           2020  14.03.2020  Everglades 50 Mile Ultra Run (USA)
# 2616900           2020  22.02.2020       Manasota Track Club 50K (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2591482                  50mi                         40             9:19:10
# 2616900                  50km                         36             4:49:16
#
#         Athlete gender  Athlete average speed  Athlete ID  Athlete_age
# 2591482              M                  8.634      222509           23
# 2616900              M                 10.371      222509           23

# %%
sns.histplot(df2['Event distance/length'])
# Out:
# <Axes: xlabel='Event distance/length', ylabel='Count'>

# %%
sns.histplot(df2, x='Event distance/length', hue='Athlete gender')
# Out:
# <Axes: xlabel='Event distance/length', ylabel='Count'>

# %%
sns.displot(df2[df2['Event distance/length']=='50mi']['Athlete average speed'])

# %%
sns.violinplot(data=df2, x='Event distance/length', y='Athlete average speed', hue='Athlete gender', split=True )
# Out:
# <Axes: xlabel='Event distance/length', ylabel='Athlete average speed'>

# %%
sns.lmplot(data=df2, x='Athlete_age', y='Athlete average speed',hue='Athlete gender')

# %%
df2.groupby(['Athlete gender','Event distance/length'])['Athlete average speed'].mean()
# Out:
# Athlete gender  Event distance/length
# F               50km                     7.083011
#                 50mi                     6.834371
# M               50km                     7.738985
#                 50mi                     7.257633
# Name: Athlete average speed, dtype: float64
